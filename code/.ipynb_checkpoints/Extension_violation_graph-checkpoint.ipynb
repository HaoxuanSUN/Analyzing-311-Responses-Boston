# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('./BUILDING AND PROPERTY VIOLATIONS.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/19/c06pzryx24qcvck9yh7zg28r0000gn/T/ipykernel_85169/2114032552.py in <module>
#       3 import numpy as np
#       4
# ----> 5 data = pd.read_csv('./BUILDING AND PROPERTY VIOLATIONS.csv')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: './BUILDING AND PROPERTY VIOLATIONS.csv'

# %%
# Get the unique values of the "violation_city" column
unique_cities = data['violation_city'].unique()

# Print the unique values
print(unique_cities)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/19/c06pzryx24qcvck9yh7zg28r0000gn/T/ipykernel_85169/444284435.py in <module>
#       1 # Get the unique values of the "violation_city" column
# ----> 2 unique_cities = data['violation_city'].unique()
#       3
#       4 # Print the unique values
#       5 print(unique_cities)
#
# NameError: name 'data' is not defined

# %%
# replace "Boston/" with "Boston" in the violation_city column
data['violation_city'] = data['violation_city'].str.replace('Boston/', 'Boston')

# %%
# group the data by violation city
grouped_data = data.groupby('violation_city').size().reset_index(name='counts')

# sort the data by violation counts
sorted_data = grouped_data.sort_values('counts', ascending=False)

# get the top three violation cities
top_cities = sorted_data.head(3)

# plot the bar chart
plt.bar(sorted_data['violation_city'], sorted_data['counts'])
plt.xticks(rotation='vertical')
plt.ylabel('Number of Violations')
plt.title('Property Violations by City')
plt.tight_layout()

# annotate the bar chart with the violation counts
for i, v in enumerate(sorted_data['counts']):
    plt.text(i, v, str(v), ha='center', va='bottom', fontsize=8)

# plot the pie chart
plt.figure(figsize=(10, 8))
plt.pie(sorted_data['counts'], labels=sorted_data['violation_city'], autopct='%1.1f%%', textprops={'color': 'black', 'weight': 'bold'})
plt.title('Property Violations by City (Percentage)')
plt.tight_layout()

# show the charts
plt.show()

# print the top three violation cities and their counts
print('The three violation cities with the most cases are:')
for index, row in top_cities.iterrows():
    print(row['violation_city'], ':', row['counts'])
# Out:
# The three violation cities with the most cases are:
# Dorchester : 3996
# Boston : 2338
# East Boston : 1544

# %%
# create bar and pie charts for the two cities with the most violations, grouped by zip code
for city in top_cities['violation_city']:
    city_data = data.loc[data['violation_city'] == city]
    zip_grouped_data = city_data.groupby(['violation_zip']).size().reset_index(name='counts')

    # create a bar chart of violation counts by zip code
    plt.figure(figsize=(10, 5))
    plt.bar(zip_grouped_data['violation_zip'], zip_grouped_data['counts'])
    plt.xlabel('Violation Zip Code')
    plt.ylabel('Number of Violations')
    plt.title(f'Property Violations in {city} by Zip Code')
    plt.xticks(rotation=45, ha='right')

    # add labels to the top of each bar
    for i, count in enumerate(zip_grouped_data['counts']):
        plt.text(i, count, str(count), ha='center', va='bottom')

    plt.tight_layout()
    plt.show()

    # create a pie chart of violation counts by zip code
    plt.figure(figsize=(10, 5))
    plt.pie(zip_grouped_data['counts'], labels=zip_grouped_data['violation_zip'], autopct='%1.1f%%', textprops={'color': 'black', 'weight': 'bold'})

    # adjust the size and spacing of the pie chart
    plt.axis('equal')
    plt.tight_layout()
    plt.show()
